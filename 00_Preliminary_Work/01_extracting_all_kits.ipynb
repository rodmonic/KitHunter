# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# From https://www.wikidata.org/wiki/Wikidata:SPARQL_query_service/queries/examples#Cats
sparql.setQuery("""
SELECT ?teamLabel ?wikipediaLink 
WHERE {
    # ?team wdt:P118 wd:Q9448;
          wdt:P31 wd:Q476028.
    # Retrieve the English Wikipedia link
    OPTIONAL {
      # ?wikipediaLink schema:about ?team;
      schema:isPartOf <https://en.wikipedia.org/>.
      }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
ORDER BY ?teamLabel
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
team_labels = [team['teamLabel']['value'].replace(" ", "_") for team in results['results']['bindings']]
team_urls = [team['wikipediaLink']['value'] for team in results['results']['bindings']]
 
teams = list(zip(team_urls, team_labels))

# %%
import wikipediaapi

# Initialize the Wikipedia API for the English language
wiki_wiki = wikipediaapi.Wikipedia('KitChaser (dominic.mccaskill@gmail.com)', 'en')


def get_images_from_page(title):
    page = wiki_wiki.page(title)
    
    if not page.exists():
        print(f"Page {title} does not exist.")
        return []
    
    # Wikipedia API provides the list of images directly
    images = page.images
    # Filter images that start with "Kit"
    kit_images = [img for img in images if img.split('/')[-1].startswith('Kit')]
    return kit_images

# Loop through the list of page titles and get the "Kit" images
for title in team_labels:
    kit_images = get_images_from_page(title)
    if kit_images:
        print(f"Images that start with 'Kit' on {title}:")
        for img in kit_images:
            print(img)
    else:
        print(f"No images starting with 'Kit' found on {title}.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 22
#      20 # Loop through the list of page titles and get the "Kit" images
#      21 for title in team_labels:
# ---> 22     kit_images = get_images_from_page(title)
#      23     if kit_images:
#      24         print(f"Images that start with 'Kit' on {title}:")
#
# Cell In[14], line 10, in get_images_from_page(title)
#       7 def get_images_from_page(title):
#       8     page = wiki_wiki.page(title)
# ---> 10     if not page.exists():
#      11         print(f"Page {title} does not exist.")
#      12         return []
#
# Cell In[14], line 10, in get_images_from_page(title)
#       7 def get_images_from_page(title):
#       8     page = wiki_wiki.page(title)
# ---> 10     if not page.exists():
#      11         print(f"Page {title} does not exist.")
#      12         return []
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1395, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1344, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
import mwclient

# Connect to the English Wikipedia
site = mwclient.Site('en.wikipedia.org')

def get_images_from_page(title):
    page = site.pages[title]
    
    # Get all images on the page
    images = page.images()
    
    # Filter images starting with "Kit"
    kit_images = []
    for img in images:
        if 'Kit' in img.name:
            # Construct the full image URL
            try:
                image_url = f"https://{site.host}{img.imageinfo['url']}"
                kit_images.append(image_url)
            except:
                pass
    
    return kit_images

# Loop through the list of page titles and get the "Kit" images
for title in team_labels:
    kit_images = get_images_from_page(title)
    if kit_images:
        print(f"Images that start with 'Kit' on {title}:")
        for img in kit_images:
            print(img)
    else:
        print(f"No images starting with 'Kit' found on {title}.")
# Out:
# Images that start with 'Kit' on AFC_Bournemouth:
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/83/Kit_body.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_body_bournemouth2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7f/Kit_left_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_left_arm_bournemouth2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_right_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_bournemouth2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/a/af/Kit_shorts.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/e/ec/Kit_shorts_bournemouth2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/9b/Kit_socks_long.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/f3/Kit_socks_redtop.png
# Images that start with 'Kit' on Arsenal_F.C.:
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/83/Kit_body.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/6/6a/Kit_body_arsenal2425T.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/c1/Kit_body_arsenal2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/f6/Kit_body_arsenal2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/1/14/Kit_body_arsenal9495a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/0c/Kit_body_bluecollarsimple.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/f9/Kit_body_collar.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/96/Kit_body_collarwhite.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7f/Kit_left_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/f9/Kit_left_arm_arsenal2425T.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/e/ed/Kit_left_arm_arsenal2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/4/42/Kit_left_arm_arsenal2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/fa/Kit_left_arm_arsenal9495a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/f5/Kit_left_arm_blueborder.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_right_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/2/24/Kit_right_arm_arsenal2425T.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/d/da/Kit_right_arm_arsenal2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/2/28/Kit_right_arm_arsenal2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/5/51/Kit_right_arm_arsenal9495a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/88/Kit_right_arm_blueborder.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/a/af/Kit_shorts.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/08/Kit_shorts_arsenal2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/6/6f/Kit_shorts_arsenal2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/d/d0/Kit_shorts_arsenal2425t.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/e/e8/Kit_socks_arsenal2425tl.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/e/e9/Kit_socks_hoops_navy.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/77/Kit_socks_hoops_white.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/9b/Kit_socks_long.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7c/Kit_socks_socks.png
# Images that start with 'Kit' on Aston_Villa_F.C.:
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/83/Kit_body.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_body_astonvilla2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/4/4e/Kit_body_astonvilla2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/86/Kit_body_lightbluehalf.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7f/Kit_left_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/fc/Kit_left_arm_astonvilla2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/d/d8/Kit_left_arm_astonvilla2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_right_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/4/4b/Kit_right_arm_astonvilla2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/76/Kit_right_arm_astonvilla2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/a/af/Kit_shorts.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/8e/Kit_shorts_adidaswhite.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/79/Kit_socks_astonvilla2425al.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/6/6e/Kit_socks_astonvilla2425hl.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/9b/Kit_socks_long.svg
# Images that start with 'Kit' on Brentford_F.C.:
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/83/Kit_body.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/07/Kit_body_brentford2324h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7f/Kit_left_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/2/23/Kit_left_arm_brentford2324h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_right_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_brentford2324h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/a/af/Kit_shorts.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/06/Kit_shorts_brentford2324h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/f/ff/Kit_socks_brentford2324hl.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/9b/Kit_socks_long.svg
# Images that start with 'Kit' on Brighton_&_Hove_Albion_F.C.:
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/83/Kit_body.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/78/Kit_body_brighton2324a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/6/67/Kit_body_brighton2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_body_brighton2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/7f/Kit_left_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/d/da/Kit_left_arm_brighton2324a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/8/8a/Kit_left_arm_brighton2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/7/72/Kit_left_arm_brighton2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_right_arm.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/2/26/Kit_right_arm_brighton2324a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/6/61/Kit_right_arm_brighton2425a.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/b/ba/Kit_right_arm_brighton2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/a/af/Kit_shorts.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/2/29/Kit_shorts_brighton2425h.png
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/9/9b/Kit_socks_long.svg
# https://en.wikipedia.orghttps://upload.wikimedia.org/wikipedia/commons/0/0d/Kit_socks_nikematchfit2021bl.png
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\listing.py:63, in List.__next__(self)
#      62 try:
# ---> 63     item = next(self._iter)
#      64     if item is not None:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 27
#      25 # Loop through the list of page titles and get the "Kit" images
#      26 for title in team_labels:
# ---> 27     kit_images = get_images_from_page(title)
#      28     if kit_images:
#      29         print(f"Images that start with 'Kit' on {title}:")
#
# Cell In[20], line 14, in get_images_from_page(title)
#      12 # Filter images starting with "Kit"
#      13 kit_images = []
# ---> 14 for img in images:
#      15     if 'Kit' in img.name:
#      16         # Construct the full image URL
#      17         try:
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\listing.py:188, in GeneratorList.__next__(self)
#     187 def __next__(self):
# --> 188     info = super(GeneratorList, self).__next__()
#     189     if info['ns'] == 14:
#     190         return Category(self.site, '', info)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\listing.py:69, in List.__next__(self)
#      67         if self.last:
#      68             raise
# ---> 69         self.load_chunk()
#      71 self.count += 1
#      72 if 'timestamp' in item:
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\listing.py:199, in GeneratorList.load_chunk(self)
#     195 def load_chunk(self):
#     196     # Put this here so that the constructor does not fail
#     197     # on uninitialized sites
#     198     self.args['iiprop'] = 'timestamp|user|comment|url|size|sha1|metadata|archivename'
# --> 199     return super(GeneratorList, self).load_chunk()
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\listing.py:99, in List.load_chunk(self)
#      83 def load_chunk(self):
#      84     """Query a new chunk of data
#      85
#      86     If the query is empty, `raise StopIteration`.
#    (...)
#      97     Else, set `self.last` to True.
#      98     """
# ---> 99     data = self.site.get(
#     100         'query', (self.generator, self.list_name),
#     101         *[(str(k), v) for k, v in self.args.items()]
#     102     )
#     103     if not data:
#     104         # Non existent page
#     105         raise StopIteration
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\client.py:300, in Site.get(self, action, *args, **kwargs)
#     288 def get(self, action, *args, **kwargs):
#     289     """Perform a generic API call using GET.
#     290
#     291     This is just a shorthand for calling api() with http_method='GET'.
#    (...)
#     298         The raw response from the API call, as a dictionary.
#     299     """
# --> 300     return self.api(action, 'GET', *args, **kwargs)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\client.py:358, in Site.api(self, action, http_method, *args, **kwargs)
#     355 sleeper = self.sleepers.make()
#     357 while True:
# --> 358     info = self.raw_api(action, http_method, **kwargs)
#     359     if not info:
#     360         info = {}
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\client.py:569, in Site.raw_api(self, action, http_method, retry_on_error, *args, **kwargs)
#     567 kwargs['format'] = 'json'
#     568 data = self._query_string(*args, **kwargs)
# --> 569 res = self.raw_call('api', data, retry_on_error=retry_on_error,
#     570                     http_method=http_method)
#     572 try:
#     573     return json.loads(res, object_pairs_hook=OrderedDict)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\mwclient\client.py:497, in Site.raw_call(self, script, data, files, retry_on_error, http_method)
#     494     args['data'] = data
#     496 try:
# --> 497     stream = self.connection.request(http_method, url, **args)
#     498     if stream.headers.get('x-database-lag'):
#     499         wait_time = int(stream.headers.get('retry-after'))
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

def get_kit_images_from_page(url):
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve {url}")
        return []

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all <img> tags
    img_tags = soup.find_all('img')
    
    # Filter images whose 'src' attribute starts with "Kit"
    kit_images = []
    for img in img_tags:
        src = img.get('src')
        if src and 'Kit' in src.split('/')[-1]:  # Check if the image filename starts with "Kit"
            # Wikipedia's image URLs start with "//", so we need to add "https:"
            full_img_url = 'https:' + src
            kit_images.append(full_img_url)
    
    return kit_images

# Loop through the list of Wikipedia URLs and get the "Kit" images in order
for url in team_urls:
    kit_images = get_kit_images_from_page(url)
    if kit_images:
        print(f"Images that start with 'Kit' on {url}:")
        for img in kit_images:
            print(img)
    else:
        print(f"No images starting with 'Kit' found on {url}.")
# Out:
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/AFC_Bournemouth:
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_left_arm_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_body_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ec/Kit_shorts_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f3/Kit_socks_redtop.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Arsenal_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/4/42/Kit_left_arm_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f6/Kit_body_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/28/Kit_right_arm_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6f/Kit_shorts_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ed/Kit_left_arm_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c1/Kit_body_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/da/Kit_right_arm_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/08/Kit_shorts_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f9/Kit_left_arm_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6a/Kit_body_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/24/Kit_right_arm_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d0/Kit_shorts_arsenal2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e8/Kit_socks_arsenal2425tl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f9/Kit_body_collar.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e9/Kit_socks_hoops_navy.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/96/Kit_body_collarwhite.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/77/Kit_socks_hoops_white.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f5/Kit_left_arm_blueborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0c/Kit_body_bluecollarsimple.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/88/Kit_right_arm_blueborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7c/Kit_socks_socks.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fa/Kit_left_arm_arsenal9495a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/14/Kit_body_arsenal9495a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/51/Kit_right_arm_arsenal9495a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Aston_Villa_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/d/d8/Kit_left_arm_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4e/Kit_body_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/76/Kit_right_arm_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6e/Kit_socks_astonvilla2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fc/Kit_left_arm_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_body_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4b/Kit_right_arm_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/79/Kit_socks_astonvilla2425al.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/86/Kit_body_lightbluehalf.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/8e/Kit_shorts_adidaswhite.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Brentford_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/2/23/Kit_left_arm_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/07/Kit_body_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/06/Kit_shorts_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/ff/Kit_socks_brentford2324hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Brighton_%26_Hove_Albion_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/7/72/Kit_left_arm_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_body_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/ba/Kit_right_arm_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/29/Kit_shorts_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/8a/Kit_left_arm_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/67/Kit_body_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/61/Kit_right_arm_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/da/Kit_left_arm_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/78/Kit_body_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/26/Kit_right_arm_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0d/Kit_socks_nikematchfit2021bl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Chelsea_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/e/e2/Kit_left_arm_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/65/Kit_body_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e2/Kit_right_arm_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/a/ab/Kit_shorts_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ee/Kit_socks_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/97/Kit_left_arm_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3f/Kit_body_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7c/Kit_right_arm_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/5e/Kit_shorts_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d4/Kit_left_arm_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_body_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_right_arm_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/1a/Kit_shorts_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/56/Kit_body_chelsea1905h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/41/Kit_socks_2whitestripes.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# No images starting with 'Kit' found on https://en.wikipedia.org/wiki/Crystal_Palace_F.C..
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Everton_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/02/Kit_body_everton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/51/Kit_shorts_everton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/71/Kit_socks_everton2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/70/Kit_left_arm_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0f/Kit_body_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7a/Kit_right_arm_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c3/Kit_socks_yellowtopl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fb/Kit_left_arm_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b6/Kit_body_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/61/Kit_right_arm_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/41/Kit_shorts_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/41/Kit_socks_everton2425tl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e8/Kit_left_arm_white_stripes.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/9c/Kit_body_whitestripes.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/40/Kit_right_arm_white_stripes.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Images that start with 'Kit' on https://en.wikipedia.org/wiki/Fulham_F.C.:
# https://upload.wikimedia.org/wikipedia/commons/a/a4/Kit_left_arm_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e0/Kit_body_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/29/Kit_right_arm_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fd/Kit_shorts_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/96/Kit_left_arm_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_body_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/54/Kit_right_arm_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ee/Kit_socks_blacktop.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d9/Kit_left_arm_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/1c/Kit_body_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7b/Kit_right_arm_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 31
#      29 # Loop through the list of Wikipedia URLs and get the "Kit" images in order
#      30 for url in team_urls:
# ---> 31     kit_images = get_kit_images_from_page(url)
#      32     if kit_images:
#      33         print(f"Images that start with 'Kit' on {url}:")
#
# Cell In[22], line 5, in get_kit_images_from_page(url)
#       4 def get_kit_images_from_page(url):
# ----> 5     response = requests.get(url)
#       7     # Check if the request was successful
#       8     if response.status_code != 200:
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connection.py:652, in HTTPSConnection.connect(self)
#     649 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 652 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     653     sock=sock,
#     654     cert_reqs=self.cert_reqs,
#     655     ssl_version=self.ssl_version,
#     656     ssl_minimum_version=self.ssl_minimum_version,
#     657     ssl_maximum_version=self.ssl_maximum_version,
#     658     ca_certs=self.ca_certs,
#     659     ca_cert_dir=self.ca_cert_dir,
#     660     ca_cert_data=self.ca_cert_data,
#     661     cert_file=self.cert_file,
#     662     key_file=self.key_file,
#     663     key_password=self.key_password,
#     664     server_hostname=server_hostname_rm_dot,
#     665     ssl_context=self.ssl_context,
#     666     tls_in_tls=tls_in_tls,
#     667     assert_hostname=self.assert_hostname,
#     668     assert_fingerprint=self.assert_fingerprint,
#     669 )
#     670 self.sock = sock_and_verified.socket
#     672 # Forwarding proxies can never have a verified target since
#     673 # the proxy is the one doing the verification. Should instead
#     674 # use a CONNECT tunnel in order to verify the target.
#     675 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connection.py:805, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     802     if is_ipaddress(normalized):
#     803         server_hostname = normalized
# --> 805 ssl_sock = ssl_wrap_socket(
#     806     sock=sock,
#     807     keyfile=key_file,
#     808     certfile=cert_file,
#     809     key_password=key_password,
#     810     ca_certs=ca_certs,
#     811     ca_cert_dir=ca_cert_dir,
#     812     ca_cert_data=ca_cert_data,
#     813     server_hostname=server_hostname,
#     814     ssl_context=context,
#     815     tls_in_tls=tls_in_tls,
#     816 )
#     818 try:
#     819     if assert_fingerprint:
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     462 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     506     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup

# List of Wikipedia page URLs
page_urls = [
    'https://en.wikipedia.org/wiki/Python_(programming_language)',
    'https://en.wikipedia.org/wiki/JavaScript',
    'https://en.wikipedia.org/wiki/Artificial_intelligence'
]

def get_kit_images_from_page(url):
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve {url}")
        return []

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all <td> tags that do not contain other <td> tags
    td_tags = [td for td in soup.find_all('td') if not td.find('td')]

    grouped_images = []

    # Loop through each <td> and find images within it
    for td in td_tags:
        images_in_td = []
        
        # Find all <img> tags within this <td>
        img_tags = td.find_all('img')
        
        for img in img_tags:
            src = img.get('src')
            if src and 'Kit' in src.split('/')[-1]:  # Check if the image filename starts with "Kit"
                full_img_url = 'https:' + src
                images_in_td.append(full_img_url)
        
        # Only add this group if we found any "Kit" images
        if images_in_td:
            grouped_images.append(images_in_td)

    return grouped_images

# Loop through the list of Wikipedia URLs and get the "Kit" images grouped by <td> tags
for url in team_urls:
    grouped_images = get_kit_images_from_page(url)
    if grouped_images:
        print(f"Grouped images that start with 'Kit' on {url}:")
        for i, group in enumerate(grouped_images, start=1):
            print(f"Group {i}:")
            for img in group:
                print(img)
    else:
        print(f"No images starting with 'Kit' found in <td> tags on {url}.")
# Out:
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/AFC_Bournemouth:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_left_arm_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_body_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ec/Kit_shorts_bournemouth2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f3/Kit_socks_redtop.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Arsenal_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/4/42/Kit_left_arm_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f6/Kit_body_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/28/Kit_right_arm_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6f/Kit_shorts_arsenal2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/e/ed/Kit_left_arm_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c1/Kit_body_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/da/Kit_right_arm_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/08/Kit_shorts_arsenal2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/f/f9/Kit_left_arm_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6a/Kit_body_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/24/Kit_right_arm_arsenal2425T.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d0/Kit_shorts_arsenal2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e8/Kit_socks_arsenal2425tl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Aston_Villa_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/d/d8/Kit_left_arm_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4e/Kit_body_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/76/Kit_right_arm_astonvilla2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/6e/Kit_socks_astonvilla2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/f/fc/Kit_left_arm_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_body_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4b/Kit_right_arm_astonvilla2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/79/Kit_socks_astonvilla2425al.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Brentford_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/2/23/Kit_left_arm_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/07/Kit_body_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/01/Kit_right_arm_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/06/Kit_shorts_brentford2324h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/ff/Kit_socks_brentford2324hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Brighton_%26_Hove_Albion_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/7/72/Kit_left_arm_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_body_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/ba/Kit_right_arm_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/29/Kit_shorts_brighton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/8/8a/Kit_left_arm_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/67/Kit_body_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/61/Kit_right_arm_brighton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/d/da/Kit_left_arm_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/78/Kit_body_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/26/Kit_right_arm_brighton2324a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0d/Kit_socks_nikematchfit2021bl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Chelsea_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/e/e2/Kit_left_arm_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/65/Kit_body_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e2/Kit_right_arm_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/a/ab/Kit_shorts_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ee/Kit_socks_chelsea2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/9/97/Kit_left_arm_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3f/Kit_body_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7c/Kit_right_arm_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/5e/Kit_shorts_chelsea2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/d/d4/Kit_left_arm_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_body_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_right_arm_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/1a/Kit_shorts_chelsea2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# No images starting with 'Kit' found in <td> tags on https://en.wikipedia.org/wiki/Crystal_Palace_F.C..
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Everton_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/02/Kit_body_everton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/51/Kit_shorts_everton2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/71/Kit_socks_everton2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/7/70/Kit_left_arm_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0f/Kit_body_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7a/Kit_right_arm_everton2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c3/Kit_socks_yellowtopl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/f/fb/Kit_left_arm_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b6/Kit_body_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/61/Kit_right_arm_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/41/Kit_shorts_everton2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/41/Kit_socks_everton2425tl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Fulham_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/a/a4/Kit_left_arm_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e0/Kit_body_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/29/Kit_right_arm_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fd/Kit_shorts_fulham2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/9/96/Kit_left_arm_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b0/Kit_body_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/54/Kit_right_arm_fulham2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ee/Kit_socks_blacktop.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/d/d9/Kit_left_arm_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/1c/Kit_body_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/7b/Kit_right_arm_fulham2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Ipswich_Town_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/3/3b/Kit_left_arm_ipswich2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d2/Kit_body_ipswich2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/31/Kit_right_arm_ipswich2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/cd/Kit_shorts_ipswich2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/72/Kit_socks_ipswich2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/1/18/Kit_left_arm_navyborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/fc/Kit_body_collarnavy.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/9c/Kit_right_arm_navyborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/14/Kit_shorts_navybottom.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c8/Kit_socks_navytop.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/2/2c/Kit_left_arm_pinkborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/16/Kit_right_arm_pinkborder.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/a/a7/Kit_shorts_pinksides.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Leicester_City_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/d/d2/Kit_left_arm_leicester2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/b/b5/Kit_body_leicester2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/8c/Kit_right_arm_leicester2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/5/53/Kit_shorts_leicester2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/2/29/Kit_left_arm_leicester2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/2f/Kit_body_leicester2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e8/Kit_right_arm_leicester2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/2f/Kit_shorts_leicester2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/f/fe/Kit_left_arm_leicester2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/67/Kit_body_leicester2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/3/3f/Kit_right_arm_leicester2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Liverpool_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/9/96/Kit_left_arm_liverpool2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/67/Kit_body_liverpool2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/0b/Kit_right_arm_liverpool2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/e2/Kit_shorts_liverpool2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/7/73/Kit_socks_liverpool2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_left_arm_liverpool2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/c/c7/Kit_body_liverpool2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d5/Kit_right_arm_liverpool2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/a/a1/Kit_shorts_liverpool2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d6/Kit_socks_liverpool2425al.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/a/a0/Kit_left_arm_liverpool2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/6/66/Kit_body_liverpool2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/f/f8/Kit_right_arm_liverpool2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_shorts_liverpool2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/d/d8/Kit_socks_liverpool2425tl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Grouped images that start with 'Kit' on https://en.wikipedia.org/wiki/Manchester_City_F.C.:
# Group 1:
# https://upload.wikimedia.org/wikipedia/commons/7/7a/Kit_left_arm_mancity2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/20/Kit_body_mancity2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/a/af/Kit_right_arm_mancity2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4d/Kit_shorts_mancity2425h.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/0/07/Kit_socks_mancity2425hl.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 2:
# https://upload.wikimedia.org/wikipedia/commons/e/e4/Kit_left_arm_mancity2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/1/1a/Kit_body_mancity2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/8/82/Kit_right_arm_mancity2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/25/Kit_shorts_mancity2425a.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/e/ec/Kit_socks_mancity2425al.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# Group 3:
# https://upload.wikimedia.org/wikipedia/commons/9/90/Kit_left_arm_mancity2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/7f/Kit_left_arm.svg/31px-Kit_left_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/2/2a/Kit_body_mancity2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/8/83/Kit_body.svg/38px-Kit_body.svg.png
# https://upload.wikimedia.org/wikipedia/commons/4/4f/Kit_right_arm_mancity2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Kit_right_arm.svg/31px-Kit_right_arm.svg.png
# https://upload.wikimedia.org/wikipedia/commons/9/9e/Kit_shorts_mancity2425t.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Kit_shorts.svg/100px-Kit_shorts.svg.png
# https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Kit_socks_long.svg/100px-Kit_socks_long.svg.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 48
#      46 # Loop through the list of Wikipedia URLs and get the "Kit" images grouped by <td> tags
#      47 for url in team_urls:
# ---> 48     grouped_images = get_kit_images_from_page(url)
#      49     if grouped_images:
#      50         print(f"Grouped images that start with 'Kit' on {url}:")
#
# Cell In[25], line 20, in get_kit_images_from_page(url)
#      17     return []
#      19 # Parse the HTML content using BeautifulSoup
# ---> 20 soup = BeautifulSoup(response.content, 'html.parser')
#      22 # Find all <td> tags that do not contain other <td> tags
#      23 td_tags = [td for td in soup.find_all('td') if not td.find('td')]
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\html\parser.py:169, in HTMLParser.goahead(self, end)
#     167 startswith = rawdata.startswith
#     168 if startswith('<', i):
# --> 169     if starttagopen.match(rawdata, i): # < + letter
#     170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#
# KeyboardInterrupt:

# %%
import os
import requests
from bs4 import BeautifulSoup

# List of search terms
search_terms = ["Kit_left_arm",
"Kit_body",
"Kit_right_arm",
"Kit_shorts"]

def get_images_by_search_terms(td, search_terms):
    """
    Returns a dictionary with search terms as keys and the list of corresponding image URLs as values.
    """
    images_by_term = {term: [] for term in search_terms}
    
    # Find all <img> tags within this <td>
    img_tags = td.find_all('img')

    for img in img_tags:
        src = img.get('src')
        if src:
            # Check if the image filename matches any of the search terms
            for term in search_terms:
                if term in src.split('/')[-1]:  # Check if the filename contains the search term

                    div_above = img.find_parent('div').find_previous('div')

                    # Get the background-color if it exists in the inline style attribute
                    if div_above and 'style' in div_above.attrs:
                        styles = div_above['style']
                        styles = styles.replace(" ","")
                        # Look for background-color in the style attribute
                        style_dict = dict(item.split(":") for item in styles.split(";") if item)

                        background_color = style_dict.get('background-color', None)

                    full_img_url = 'https:' + src
                    images_by_term[term].append((full_img_url, background_color))

    return images_by_term

def get_grouped_images_by_td_and_terms(url, search_terms):
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        print(f"Failed to retrieve {url}")
        return []

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all <td> tags that do not contain other <td> tags
    td_tags = [td for td in soup.find_all('td') if not td.find('td')]

    grouped_images = []

    # Loop through each <td> and find images within it by search terms
    for td in td_tags:
        images_by_term = get_images_by_search_terms(td, search_terms)
        
        # Only add this group if we found any images for any search term
        if any(images_by_term[term] for term in search_terms):
            grouped_images.append(images_by_term)

    return grouped_images

def download_images(grouped_images, team_name, year):
    # Create the team directory if it doesn't exist
    team_dir = os.path.join('downloads', team_name, str(year))
    os.makedirs(team_dir, exist_ok=True)

    # Loop through the image groups (by <td>)
    for i, group in enumerate(grouped_images, start=1):
        group_dir = os.path.join(team_dir, f'Group_{i}')
        os.makedirs(group_dir, exist_ok=True)
        
        # Loop through each search term's images in the group
        for term, images in group.items():

            # Download each image
            img_response = requests.get(images[0][0])
            if img_response.status_code == 200:
                # Save the image in the corresponding term folder
                img_filename = os.path.join(group_dir, f'{term}-{images[0][1]}.{images[0][0].split(".")[-1]}')
                with open(img_filename, 'wb') as img_file:
                    img_file.write(img_response.content)
                print(f"Downloaded {img_filename}")
            else:
                print(f"Failed to download image {images[0]}")



# Loop through the list of Wikipedia URLs, get the images grouped by <td> and search terms, and download them
for team in team_labels:

    for year in range(2025, 2020, -1):

        url_template = f"https://en.wikipedia.org/wiki/{year-1}–{abs(year) % 100}_{team}_season"

        grouped_images = get_grouped_images_by_td_and_terms(url_template, search_terms)
        if grouped_images:
            print(f"Downloading images for team {team}...")
            download_images(grouped_images, team, year)
        else:
            print(f"No images matching search terms found for team {team}.")
# Out:
# Downloading images for team AFC_Bournemouth...
# Downloaded downloads\AFC_Bournemouth\2025\Group_1\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2025\Group_1\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2025\Group_1\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2025\Group_1\Kit_shorts-None.png
# Downloading images for team AFC_Bournemouth...
# Downloaded downloads\AFC_Bournemouth\2024\Group_1\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_1\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_1\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_1\Kit_shorts-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_2\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_2\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_2\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_2\Kit_shorts-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_3\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_3\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_3\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2024\Group_3\Kit_shorts-#000040.png
# Downloading images for team AFC_Bournemouth...
# Downloaded downloads\AFC_Bournemouth\2023\Group_1\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_1\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_1\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_1\Kit_shorts-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_2\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_2\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_2\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_2\Kit_shorts-#5868D9.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_3\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_3\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_3\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2023\Group_3\Kit_shorts-#000000.png
# Downloading images for team AFC_Bournemouth...
# Downloaded downloads\AFC_Bournemouth\2022\Group_1\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_1\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_1\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_1\Kit_shorts-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_2\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_2\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_2\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2022\Group_2\Kit_shorts-None.png
# Downloading images for team AFC_Bournemouth...
# Downloaded downloads\AFC_Bournemouth\2021\Group_1\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_1\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_1\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_1\Kit_shorts-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_2\Kit_left_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_2\Kit_body-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_2\Kit_right_arm-None.png
# Downloaded downloads\AFC_Bournemouth\2021\Group_2\Kit_shorts-None.png
# Downloading images for team Arsenal_F.C....
# Downloaded downloads\Arsenal_F.C.\2025\Group_1\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_1\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_1\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_1\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_2\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_2\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_2\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_2\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_3\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_3\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_3\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_3\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_4\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_4\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_4\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_4\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_5\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_5\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_5\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_5\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_6\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_6\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_6\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_6\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_7\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_7\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_7\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_7\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_8\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_8\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_8\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_8\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_9\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_9\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_9\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_9\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_10\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_10\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_10\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_10\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_11\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_11\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_11\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2025\Group_11\Kit_shorts-None.png
# Downloading images for team Arsenal_F.C....
# Downloaded downloads\Arsenal_F.C.\2024\Group_1\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_1\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_1\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_1\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_2\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_2\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_2\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_2\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_3\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_3\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_3\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_3\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_4\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_4\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_4\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_4\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_5\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_5\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_5\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_5\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_6\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_6\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_6\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_6\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_7\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_7\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_7\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_7\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_8\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_8\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_8\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_8\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_9\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_9\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_9\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_9\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_10\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_10\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_10\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_10\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_11\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_11\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_11\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_11\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_12\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_12\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_12\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_12\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_13\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_13\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_13\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2024\Group_13\Kit_shorts-None.png
# Downloading images for team Arsenal_F.C....
# Downloaded downloads\Arsenal_F.C.\2023\Group_1\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_1\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_1\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_1\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_2\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_2\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_2\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_2\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_3\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_3\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_3\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_3\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_4\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_4\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_4\Kit_right_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_4\Kit_shorts-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_5\Kit_left_arm-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_5\Kit_body-None.png
# Downloaded downloads\Arsenal_F.C.\2023\Group_5\Kit_right_arm-None.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 105
#     103 if grouped_images:
#     104     print(f"Downloading images for team {team}...")
# --> 105     download_images(grouped_images, team, year)
#     106 else:
#     107     print(f"No images matching search terms found for team {team}.")
#
# Cell In[36], line 83, in download_images(grouped_images, team_name, year)
#      79 # Loop through each search term's images in the group
#      80 for term, images in group.items():
#      81
#      82     # Download each image
# ---> 83     img_response = requests.get(images[0][0])
#      84     if img_response.status_code == 200:
#      85         # Save the image in the corresponding term folder
#      86         img_filename = os.path.join(group_dir, f'{term}-{images[0][1]}.{images[0][0].split(".")[-1]}')
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\DominicMcCaskill\repos\KitHunter\.venv\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\DominicMcCaskill\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from PIL import Image

# Define the path to the existing image and the new output file
input_image_path = './downloads/AFC_Bournemouth/2023/Group_2/Kit_shorts-#5868D9.png'
output_image_path = './downloads/AFC_Bournemouth/2023/Group_2/image_with_background.png'

# Define the new background color (R, G, B)
background_color = (255, 0, 0)  # Red background

# Open the existing image
existing_image = Image.open(input_image_path)

# Get the size of the existing image
width, height = existing_image.size

# Create a new image with the same size and the background color
background = Image.new('RGB', (width, height), background_color)

# Paste the existing image onto the background
# We use the alpha channel if the existing image has transparency
background.paste(existing_image, (0, 0), existing_image.convert('RGBA'))

# Save the new image
background.save(output_image_path)

print(f"Image with background color created and saved as '{output_image_path}'")
# Out:
# Image with background color created and saved as './downloads/AFC_Bournemouth/2023/Group_2/image_with_background.png'
